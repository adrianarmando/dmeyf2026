# %% [markdown]
# # Tarea para el Hogar 04

# %% [markdown]
# ##  1. Overfitting the Public Leaderboard

# %% [markdown]
# Leer  https://medium.com/hmif-itb/overfitting-the-leaderboard-da25172ac62e
# ( 8 minutos )

# %% [markdown]
# ## 2. Hiperparámetros del LightGBM

# %% [markdown]
# Los objetivos de esta tarea son:
#
#
# *   Aumentar la rentabilidad de la campaña de marketing de retención proactiva de clientes.
# *   Generar un mejor modelo optimizando sus hiperparámetros
# *   Conceptual : investigar los mas relevantes hiperparámetros de LightGBM
# *   Familiarizarse con el uso de máquinas virtuales de Google Colab
# *   Ver un pipeline completo de optimización de hiperparámetros y puesta en producción

# %% [markdown]
# LightGBM cuenta con mas de 60 hiperparámetros, siendo posible utilizar 40 al mismo tiempo, aunque no razonable.
# <br> La documentación oficial de los hiperparámetros de LightGBM es  https://lightgbm.readthedocs.io/en/latest/Parameters.html#core-parameters

# %% [markdown]
# Se lo alerta sobre que una Optimizacion sw Hiperparámetros lleva varias horas de corrida, y usted deberá correr VARIAS optimizaciones para descubrir cuales parámetros conviene optimizar.

# %% [markdown]
# Es necesario investigar cuales son los hiperparámetros de LightGBM que vale la pena optimizar, ya que los realmente utiles son apenas un reducido subconjunto.
# <br>Usted deberá investigar cuales son los hiperparámetros mas relevantes de LightGBM, su primer alternativa es preguntándole a su amigo con capacidades especiales ChatGPT o sus endogámicos familiares Claude, DeepSeek, Gemini, Grok, etc
# <br> La segunda alternativa es la propia documentación de LightGBM  https://lightgbm.readthedocs.io/en/latest/Parameters-Tuning.html

# %% [markdown]
# Adicionalmente podra buscar información como la que proveen esta diminuta muestra aleatoria de artículos ligeros:
# * https://machinelearningmastery.com/light-gradient-boosted-machine-lightgbm-ensemble/
# *  https://medium.com/@sarahzouinina/a-deep-dive-into-lightgbm-how-to-choose-and-tune-parameters-7c584945842e
# *  https://www.kaggle.com/code/somang1418/tuning-hyperparameters-under-10-minutes-lgbm
# *  https://towardsdatascience.com/beginners-guide-to-the-must-know-lightgbm-hyperparameters-a0005a812702/
#
#
# <br>  La muestra anterior se brinda a modo de ejemplo, usted deberá buscar muuuuchas  fuentes adicionales de información
# <br> Tenga presente que LightGBM es el estado del arte en modelado predictivo para datasets estructurado, que son el 90% del trabajo del 95% de los Data Scientists en Argentina.

# %% [markdown]
# El desafío de esta tarea es:
# * Qué hiperparparámetros conviene optimizar?  Las recomendaciones de los artículos ligeros es siempre sensata?  Sus autores realmente hicieron experimentos o son siemplemente escritores de entretenimiento carente de base científica?
# * Elegidos los hiperparámetros, cual es el  <desde, hasta> que se debe utilizar en la Bayesian Optimization ?
# * Realmente vale la pena optimizar 10 o 16 hiperparámetros al mismo tiempo ?  No resulta contraproducente una búsqueda en un espacio de tal alta dimensionalidad ?

# %% [markdown]
# #### 2.1  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')
# Out:
# Mounted at /content/.drive

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/dmeyf"
mkdir -p "/content/buckets"
ln -sfn "/content/.drive/My Drive/dmeyf"   /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets


# defino funcion descargar()
descargar() {
  carpeta_destino="/content/buckets/b1/datasets/"
  url_origen="https://storage.googleapis.com/open-courses/utn2026-b40a/"
  archivo="$1"

  if ! test -f "$carpeta_destino""$archivo"; then
    wget  "$url_origen""$archivo"  -O "$carpeta_destino""$archivo"
  fi

  if ! test -f  "/content/datasets/""$archivo"; then
    cp  "$carpeta_destino""$archivo"  "/content/datasets/""$archivo"
  fi;
}

# hago la descarga efectiva, llamando a descargar()
descargar  "dataset_pequeno.csv"

# %% [markdown]
# ### 2.2 Optimizacion Hiperparámetros

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje R Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# ### 2.2.1 Inicio

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Fri Aug 28 10:48:02 PM 2026"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  671287 35.9 1473300    78.7 1473300  78.7
# Vcells 1242646  9.5 8388608    64.0 1978711  15.1

# %% [markdown]
# ### 2.2.2 Carga de Librerias

# %%
# cargo las librerias que necesito
require("data.table")
require("parallel")

if( !require("primes") ) install.packages("primes")
require("primes")

if( !require("utils") ) install.packages("utils")
require("utils")

if( !require("rlist") ) install.packages("rlist")
require("rlist")

if( !require("yaml")) install.packages("yaml")
require("yaml")

if( !require("lightgbm") ) install.packages("lightgbm")
require("lightgbm")
# Out:
# Loading required package: data.table
#
#
# Attaching package: ‘data.table’
#
#
# The following object is masked from ‘package:base’:
#
#     %notin%
#
#
# Loading required package: parallel
#
# Loading required package: primes
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘primes’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: primes
#
# Loading required package: rlist
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘rlist’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘XML’
#
#
# Loading required package: rlist
#
# Loading required package: yaml
#
# Loading required package: lightgbm
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘lightgbm’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: lightgbm

# %% [markdown]
# ### 2.2.3 Definicion de Parametros

# %% [markdown]
# aqui debe cargar SU semilla primigenia
# <br>recuerde cambiar el numero de experimento en cada corrida nueva

# %%
PARAM <- list()
PARAM$experimento <- '5940_03'

PARAM$semilla_primigenia <- 115879

# %%
PARAM$kaggle$competencia <- "utn-2026-inicial"
PARAM$kaggle$cortes <- seq(9000, 12000, by= 500)

# %%
# un undersampling de 0.1  toma solo el 10% de los CONTINUA
# undersampling de 1.0  implica tomar TODOS los datos

PARAM$trainingstrategy$undersampling <- 0.5

# %%
# Parametros LightGBM

PARAM$hyperparametertuning$xval_folds <- 5

# parametros fijos del LightGBM que se pisaran con la parte variable de la BO
PARAM$lgbm$param_fijos <-  list(
  boosting= "gbdt", # puede ir  dart  , ni pruebe random_forest
  objective= "binary",
  metric= "auc",
  first_metric_only= FALSE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  force_row_wise= TRUE, # para reducir warnings
  verbosity= -100,

  seed= PARAM$semilla_primigenia,

  max_depth= -1L, # -1 significa no limitar,  por ahora lo dejo fijo
  min_gain_to_split= 0, # min_gain_to_split >= 0
  min_sum_hessian_in_leaf= 0.001, #  min_sum_hessian_in_leaf >= 0.0
  lambda_l1= 0.0, # lambda_l1 >= 0.0
  lambda_l2= 0.0, # lambda_l2 >= 0.0
  max_bin= 31L, # lo debo dejar fijo, no participa de la BO

  bagging_fraction= 1.0, # 0.0 < bagging_fraction <= 1.0
  pos_bagging_fraction= 1.0, # 0.0 < pos_bagging_fraction <= 1.0
  neg_bagging_fraction= 1.0, # 0.0 < neg_bagging_fraction <= 1.0
  is_unbalance= FALSE, #
  scale_pos_weight= 1.0, # scale_pos_weight > 0.0

  drop_rate= 0.1, # 0.0 < neg_bagging_fraction <= 1.0
  max_drop= 50, # <=0 means no limit
  skip_drop= 0.5, # 0.0 <= skip_drop <= 1.0

  extra_trees= FALSE,

  num_iterations= 100,
  learning_rate= 0.10,  # >=0
  feature_fraction= 1.0, # 0 < ff <= 1.0
  num_leaves= 32, # integer >= 2
  min_data_in_leaf= 20 # integer >= 0
)

# %% [markdown]
# ### 2.2.4  Preprocesamiento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("HT", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %%
# lectura del dataset

dataset <- fread("/content/datasets/dataset_pequeno.csv")

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# paso la clase a binaria que tome valores {0,1}  enteros
#  BAJA+1 y BAJA+2  son  1,   CONTINUA es 0

dataset_train[,
  clase01 := ifelse(clase_ternaria %in% c("BAJA+2","BAJA+1"), 1L, 0L)
]

# %%
# defino los datos que forma parte del training
# aqui se hace el undersampling de los CONTINUA

set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset_train[, azar := runif(nrow(dataset_train))]
dataset_train[, training := 0L]

dataset_train[
  foto_mes %in% c(202107) &
    (azar <= PARAM$trainingstrategy$undersampling | clase_ternaria %in% c("BAJA+1", "BAJA+2")),
  training := 1L
]

# %%
# los campos que se van a utilizar

campos_buenos <- setdiff(
  colnames(dataset_train),
  c("clase_ternaria", "clase01", "azar", "training")
)

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[training == 1L, campos_buenos, with= FALSE]),
  label= dataset_train[training == 1L, clase01],
  free_raw_data= FALSE
)

nrow(dtrain)
ncol(dtrain)
# Out:
# [1] 83081
# [1] 154

# %% [markdown]
# 2.2.5 Configuracion del Grid Search

# %%
# En el argumento x llegan los parmaetros de LightGBM
#  devuelve la AUC en cross validation del modelo entrenado

Estimar_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelocv <- lgb.cv(
    data= dtrain,
    nfold= PARAM$hyperparametertuning$xval_folds,
    stratified= TRUE,
    param= param_completo
  )

  # obtengo la ganancia
  AUC <- modelocv$best_score

  # hago espacio en la memoria
  rm(modelocv)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y  "),
    toString(x),
    " AUC ", AUC
  )

  return(AUC)
}

# %%
# lo que sigue a continuacion es una forma alternativa a los loops anidados
# creo una tabla con el producto cartesiano de los vectores
# Experimento 594_02
# tb_nueva <- CJ(
#   learning_rate    = c(0.015, 0.025, 0.035),
#   num_leaves       = c(90, 140, 200),
#   min_data_in_leaf = c(150, 300),
#   feature_fraction = c(0.30, 0.40, 0.50),
#   num_iterations   = c(500, 700)
# )

# Experimento 594_03
tb_nueva <- CJ(
  learning_rate    = c(0.02, 0.03),
  num_leaves       = c(70, 100, 130),
  min_data_in_leaf = c(250, 400, 600),
  feature_fraction = c(0.35, 0.45),
  lambda_l1        = c(0.0, 1.0),
  num_iterations   = 600
)

# %%
# veo que tiene la tabla antes de procesar
tb_nueva
# Out:
#     learning_rate num_leaves min_data_in_leaf feature_fraction num_iterations
# 1   0.015          90        150              0.3              500
# 2   0.015          90        150              0.3              700
# 3   0.015          90        150              0.4              500
# 4   0.015          90        150              0.4              700
# 5   0.015          90        150              0.5              500
# 6   0.015          90        150              0.5              700
# 7   0.015          90        300              0.3              500
# 8   0.015          90        300              0.3              700
# 9   0.015          90        300              0.4              500
# 10  0.015          90        300              0.4              700
# 11  0.015          90        300              0.5              500
# 12  0.015          90        300              0.5              700
# 13  0.015         140        150              0.3              500
# 14  0.015         140        150              0.3              700
# 15  0.015         140        150              0.4              500
# 16  0.015         140        150              0.4              700
# 17  0.015         140        150              0.5              500
# 18  0.015         140        150              0.5              700
# 19  0.015         140        300              0.3              500
# 20  0.015         140        300              0.3              700
# 21  0.015         140        300              0.4              500
# 22  0.015         140        300              0.4              700
# 23  0.015         140        300              0.5              500
# 24  0.015         140        300              0.5              700
# 25  0.015         200        150              0.3              500
# 26  0.015         200        150              0.3              700
# 27  0.015         200        150              0.4              500
# 28  0.015         200        150              0.4              700
# 29  0.015         200        150              0.5              500
# 30  0.015         200        150              0.5              700
# ⋮   ⋮             ⋮          ⋮                ⋮                ⋮
# 79  0.035          90        300              0.3              500
# 80  0.035          90        300              0.3              700
# 81  0.035          90        300              0.4              500
# 82  0.035          90        300              0.4              700
# 83  0.035          90        300              0.5              500
# 84  0.035          90        300              0.5              700
# 85  0.035         140        150              0.3              500
# 86  0.035         140        150              0.3              700
# 87  0.035         140        150              0.4              500
# 88  0.035         140        150              0.4              700
# 89  0.035         140        150              0.5              500
# 90  0.035         140        150              0.5              700
# 91  0.035         140        300              0.3              500
# 92  0.035         140        300              0.3              700
# 93  0.035         140        300              0.4              500
# 94  0.035         140        300              0.4              700
# 95  0.035         140        300              0.5              500
# 96  0.035         140        300              0.5              700
# 97  0.035         200        150              0.3              500
# 98  0.035         200        150              0.3              700
# 99  0.035         200        150              0.4              500
# 100 0.035         200        150              0.4              700
# 101 0.035         200        150              0.5              500
# 102 0.035         200        150              0.5              700
# 103 0.035         200        300              0.3              500
# 104 0.035         200        300              0.3              700
# 105 0.035         200        300              0.4              500
# 106 0.035         200        300              0.4              700
# 107 0.035         200        300              0.5              500
# 108 0.035         200        300              0.5              700

# %%
# registro a registro calculo la AUC
tb_nueva[, AUC:= Estimar_AUC_lightgbm( list(.SD)),
  by=1:nrow(tb_nueva) ]
# Out:
# Fri Aug 28 10:58:39 PM 2026  list(learning_rate = 0.015, num_leaves = 90, min_data_in_leaf = 150, feature_fraction = 0.3, num_iterations = 500) AUC 0.925893460664036
#
# Fri Aug 28 10:58:55 PM 2026  list(learning_rate = 0.015, num_leaves = 90, min_data_in_leaf = 150, feature_fraction = 0.3, num_iterations = 700) AUC 0.924973964875888
#
# Fri Aug 28 10:59:11 PM 2026  list(learning_rate = 0.015, num_leaves = 90, min_data_in_leaf = 150, feature_fraction = 0.4, num_iterations = 500) AUC 0.926631616313201
#
# Fri Aug 28 10:59:30 PM 2026  list(learning_rate = 0.015, num_leaves = 90, min_data_in_leaf = 150, feature_fraction = 0.4, num_iterations = 700) AUC 0.925268741275167
#
# Fri Aug 28 10:59:46 PM 2026  list(learning_rate = 0.015, num_leaves = 90, min_data_in_leaf = 150, feature_fraction = 0.5, num_iterations = 500) AUC 0.925317751186717
#
# Fri Aug 28 11:00:01 PM 2026  list(learning_rate = 0.015, num_leaves = 90, min_data_in_leaf = 150, feature_fraction = 0.5, num_iterations = 700) AUC 0.925873578603952
#
# Fri Aug 28 11:00:18 PM 2026  list(learning_rate = 0.015, num_leaves = 90, min_data_in_leaf = 300, feature_fraction = 0.3, num_iterations = 500) AUC 0.926707233436348
#
# Fri Aug 28 11:00:34 PM 2026  list(learning_rate = 0.015, num_leaves = 90, min_data_in_leaf = 300, feature_fraction = 0.3, num_iterations = 700) AUC 0.92670759291981
#
# Fri Aug 28 11:00:49 PM 2026  list(learning_rate = 0.015, num_leaves = 90, min_data_in_leaf = 300, feature_fraction = 0.4, num_iterations = 500) AUC 0.924365299056784
#
# Fri Aug 28 11:01:05 PM 2026  list(learning_rate = 0.015, num_leaves = 90, min_data_in_leaf = 300, feature_fraction = 0.4, num_iterations = 700) AUC 0.926353077555699
#
# Fri Aug 28 11:01:21 PM 2026  list(learning_rate = 0.015, num_leaves = 90, min_data_in_leaf = 300, feature_fraction = 0.5, num_iterations = 500) AUC 0.925649421318558
#
# Fri Aug 28 11:01:36 PM 2026  list(learning_rate = 0.015, num_leaves = 90, min_data_in_leaf = 300, feature_fraction = 0.5, num_iterations = 700) AUC 0.924743995155653
#
# Fri Aug 28 11:01:52 PM 2026  list(learning_rate = 0.015, num_leaves = 140, min_data_in_leaf = 150, feature_fraction = 0.3, num_iterations = 500) AUC 0.925702102758177
#
# Fri Aug 28 11:02:08 PM 2026  list(learning_rate = 0.015, num_leaves = 140, min_data_in_leaf = 150, feature_fraction = 0.3, num_iterations = 700) AUC 0.925132167823485
#
# Fri Aug 28 11:02:23 PM 2026  list(learning_rate = 0.015, num_leaves = 140, min_data_in_leaf = 150, feature_fraction = 0.4, num_iterations = 500) AUC 0.926060010463524
#
# Fri Aug 28 11:02:39 PM 2026  list(learning_rate = 0.015, num_leaves = 140, min_data_in_leaf = 150, feature_fraction = 0.4, num_iterations = 700) AUC 0.925018726878919
#
# Fri Aug 28 11:02:56 PM 2026  list(learning_rate = 0.015, num_leaves = 140, min_data_in_leaf = 150, feature_fraction = 0.5, num_iterations = 500) AUC 0.925777100006859
#
# Fri Aug 28 11:03:12 PM 2026  list(learning_rate = 0.015, num_leaves = 140, min_data_in_leaf = 150, feature_fraction = 0.5, num_iterations = 700) AUC 0.926443942153628
#
# Fri Aug 28 11:03:28 PM 2026  list(learning_rate = 0.015, num_leaves = 140, min_data_in_leaf = 300, feature_fraction = 0.3, num_iterations = 500) AUC 0.925007945112173
#
# Fri Aug 28 11:03:43 PM 2026  list(learning_rate = 0.015, num_leaves = 140, min_data_in_leaf = 300, feature_fraction = 0.3, num_iterations = 700) AUC 0.925748597801058
#
# Fri Aug 28 11:03:59 PM 2026  list(learning_rate = 0.015, num_leaves = 140, min_data_in_leaf = 300, feature_fraction = 0.4, num_iterations = 500) AUC 0.925979641683861
#
# Fri Aug 28 11:04:14 PM 2026  list(learning_rate = 0.015, num_leaves = 140, min_data_in_leaf = 300, feature_fraction = 0.4, num_iterations = 700) AUC 0.925930721290552
#
# Fri Aug 28 11:04:29 PM 2026  list(learning_rate = 0.015, num_leaves = 140, min_data_in_leaf = 300, feature_fraction = 0.5, num_iterations = 500) AUC 0.924518128896789
#
# Fri Aug 28 11:04:44 PM 2026  list(learning_rate = 0.015, num_leaves = 140, min_data_in_leaf = 300, feature_fraction = 0.5, num_iterations = 700) AUC 0.925437192158561
#
# Fri Aug 28 11:05:01 PM 2026  list(learning_rate = 0.015, num_leaves = 200, min_data_in_leaf = 150, feature_fraction = 0.3, num_iterations = 500) AUC 0.925413219357293
#
# Fri Aug 28 11:05:16 PM 2026  list(learning_rate = 0.015, num_leaves = 200, min_data_in_leaf = 150, feature_fraction = 0.3, num_iterations = 700) AUC 0.92808302732527
#
# Fri Aug 28 11:05:32 PM 2026  list(learning_rate = 0.015, num_leaves = 200, min_data_in_leaf = 150, feature_fraction = 0.4, num_iterations = 500) AUC 0.925612926855479
#
# Fri Aug 28 11:05:48 PM 2026  list(learning_rate = 0.015, num_leaves = 200, min_data_in_leaf = 150, feature_fraction = 0.4, num_iterations = 700) AUC 0.926481839633192
#
# Fri Aug 28 11:06:04 PM 2026  list(learning_rate = 0.015, num_leaves = 200, min_data_in_leaf = 150, feature_fraction = 0.5, num_iterations = 500) AUC 0.923683794039678
#
# Fri Aug 28 11:06:19 PM 2026  list(learning_rate = 0.015, num_leaves = 200, min_data_in_leaf = 150, feature_fraction = 0.5, num_iterations = 700) AUC 0.925092779242431
#
# Fri Aug 28 11:06:34 PM 2026  list(learning_rate = 0.015, num_leaves = 200, min_data_in_leaf = 300, feature_fraction = 0.3, num_iterations = 500) AUC 0.925337895524504
#
# Fri Aug 28 11:06:52 PM 2026  list(learning_rate = 0.015, num_leaves = 200, min_data_in_leaf = 300, feature_fraction = 0.3, num_iterations = 700) AUC 0.925414980311281
#
# Fri Aug 28 11:07:07 PM 2026  list(learning_rate = 0.015, num_leaves = 200, min_data_in_leaf = 300, feature_fraction = 0.4, num_iterations = 500) AUC 0.924736137423397
#
# Fri Aug 28 11:07:23 PM 2026  list(learning_rate = 0.015, num_leaves = 200, min_data_in_leaf = 300, feature_fraction = 0.4, num_iterations = 700) AUC 0.924984454287048
#
# Fri Aug 28 11:07:41 PM 2026  list(learning_rate = 0.015, num_leaves = 200, min_data_in_leaf = 300, feature_fraction = 0.5, num_iterations = 500) AUC 0.9262451605964
#
# Fri Aug 28 11:07:56 PM 2026  list(learning_rate = 0.015, num_leaves = 200, min_data_in_leaf = 300, feature_fraction = 0.5, num_iterations = 700) AUC 0.925528247264944
#
# Fri Aug 28 11:08:12 PM 2026  list(learning_rate = 0.025, num_leaves = 90, min_data_in_leaf = 150, feature_fraction = 0.3, num_iterations = 500) AUC 0.924264412490647
#
# Fri Aug 28 11:08:28 PM 2026  list(learning_rate = 0.025, num_leaves = 90, min_data_in_leaf = 150, feature_fraction = 0.3, num_iterations = 700) AUC 0.92574190541881
#
# Fri Aug 28 11:08:45 PM 2026  list(learning_rate = 0.025, num_leaves = 90, min_data_in_leaf = 150, feature_fraction = 0.4, num_iterations = 500) AUC 0.924171024016236
#
# Fri Aug 28 11:09:00 PM 2026  list(learning_rate = 0.025, num_leaves = 90, min_data_in_leaf = 150, feature_fraction = 0.4, num_iterations = 700) AUC 0.926592196359223
#
# Fri Aug 28 11:09:17 PM 2026  list(learning_rate = 0.025, num_leaves = 90, min_data_in_leaf = 150, feature_fraction = 0.5, num_iterations = 500) AUC 0.926028996522924
#
# Fri Aug 28 11:09:32 PM 2026  list(learning_rate = 0.025, num_leaves = 90, min_data_in_leaf = 150, feature_fraction = 0.5, num_iterations = 700) AUC 0.92469185253747
#
# Fri Aug 28 11:09:50 PM 2026  list(learning_rate = 0.025, num_leaves = 90, min_data_in_leaf = 300, feature_fraction = 0.3, num_iterations = 500) AUC 0.926957084441129
#
# Fri Aug 28 11:10:05 PM 2026  list(learning_rate = 0.025, num_leaves = 90, min_data_in_leaf = 300, feature_fraction = 0.3, num_iterations = 700) AUC 0.925448288376191
#
# Fri Aug 28 11:10:21 PM 2026  list(learning_rate = 0.025, num_leaves = 90, min_data_in_leaf = 300, feature_fraction = 0.4, num_iterations = 500) AUC 0.925726658612494
#
# Fri Aug 28 11:10:36 PM 2026  list(learning_rate = 0.025, num_leaves = 90, min_data_in_leaf = 300, feature_fraction = 0.4, num_iterations = 700) AUC 0.925379809549863
#
# Fri Aug 28 11:10:52 PM 2026  list(learning_rate = 0.025, num_leaves = 90, min_data_in_leaf = 300, feature_fraction = 0.5, num_iterations = 500) AUC 0.926760055117046
#
# Fri Aug 28 11:11:07 PM 2026  list(learning_rate = 0.025, num_leaves = 90, min_data_in_leaf = 300, feature_fraction = 0.5, num_iterations = 700) AUC 0.925971890589383
#
# Fri Aug 28 11:11:22 PM 2026  list(learning_rate = 0.025, num_leaves = 140, min_data_in_leaf = 150, feature_fraction = 0.3, num_iterations = 500) AUC 0.925332967021955
#
# Fri Aug 28 11:11:38 PM 2026  list(learning_rate = 0.025, num_leaves = 140, min_data_in_leaf = 150, feature_fraction = 0.3, num_iterations = 700) AUC 0.925218237945388
#
# Fri Aug 28 11:11:54 PM 2026  list(learning_rate = 0.025, num_leaves = 140, min_data_in_leaf = 150, feature_fraction = 0.4, num_iterations = 500) AUC 0.925783061677954
#
# Fri Aug 28 11:12:10 PM 2026  list(learning_rate = 0.025, num_leaves = 140, min_data_in_leaf = 150, feature_fraction = 0.4, num_iterations = 700) AUC 0.925168721469686
#
# Fri Aug 28 11:12:24 PM 2026  list(learning_rate = 0.025, num_leaves = 140, min_data_in_leaf = 150, feature_fraction = 0.5, num_iterations = 500) AUC 0.926714392498404
#
# Fri Aug 28 11:12:40 PM 2026  list(learning_rate = 0.025, num_leaves = 140, min_data_in_leaf = 150, feature_fraction = 0.5, num_iterations = 700) AUC 0.926388285990871
#
# Fri Aug 28 11:12:56 PM 2026  list(learning_rate = 0.025, num_leaves = 140, min_data_in_leaf = 300, feature_fraction = 0.3, num_iterations = 500) AUC 0.924657145826612
#
# Fri Aug 28 11:13:12 PM 2026  list(learning_rate = 0.025, num_leaves = 140, min_data_in_leaf = 300, feature_fraction = 0.3, num_iterations = 700) AUC 0.926015482242204
#
# Fri Aug 28 11:13:29 PM 2026  list(learning_rate = 0.025, num_leaves = 140, min_data_in_leaf = 300, feature_fraction = 0.4, num_iterations = 500) AUC 0.925182471018818
#
# Fri Aug 28 11:13:46 PM 2026  list(learning_rate = 0.025, num_leaves = 140, min_data_in_leaf = 300, feature_fraction = 0.4, num_iterations = 700) AUC 0.926348211621625
#
# Fri Aug 28 11:14:01 PM 2026  list(learning_rate = 0.025, num_leaves = 140, min_data_in_leaf = 300, feature_fraction = 0.5, num_iterations = 500) AUC 0.925899424169131
#
# Fri Aug 28 11:14:17 PM 2026  list(learning_rate = 0.025, num_leaves = 140, min_data_in_leaf = 300, feature_fraction = 0.5, num_iterations = 700) AUC 0.924843614984916
#
# Fri Aug 28 11:14:32 PM 2026  list(learning_rate = 0.025, num_leaves = 200, min_data_in_leaf = 150, feature_fraction = 0.3, num_iterations = 500) AUC 0.925288369706547
#
# Fri Aug 28 11:14:47 PM 2026  list(learning_rate = 0.025, num_leaves = 200, min_data_in_leaf = 150, feature_fraction = 0.3, num_iterations = 700) AUC 0.925374727778756
#
# Fri Aug 28 11:15:03 PM 2026  list(learning_rate = 0.025, num_leaves = 200, min_data_in_leaf = 150, feature_fraction = 0.4, num_iterations = 500) AUC 0.925646421071944
#
# Fri Aug 28 11:15:18 PM 2026  list(learning_rate = 0.025, num_leaves = 200, min_data_in_leaf = 150, feature_fraction = 0.4, num_iterations = 700) AUC 0.927364438503191
#
# Fri Aug 28 11:15:32 PM 2026  list(learning_rate = 0.025, num_leaves = 200, min_data_in_leaf = 150, feature_fraction = 0.5, num_iterations = 500) AUC 0.924537978444183
#
# Fri Aug 28 11:15:48 PM 2026  list(learning_rate = 0.025, num_leaves = 200, min_data_in_leaf = 150, feature_fraction = 0.5, num_iterations = 700) AUC 0.926217451760103
#
# Fri Aug 28 11:16:03 PM 2026  list(learning_rate = 0.025, num_leaves = 200, min_data_in_leaf = 300, feature_fraction = 0.3, num_iterations = 500) AUC 0.924092559579809
#
# Fri Aug 28 11:16:18 PM 2026  list(learning_rate = 0.025, num_leaves = 200, min_data_in_leaf = 300, feature_fraction = 0.3, num_iterations = 700) AUC 0.925837515551725
#
# Fri Aug 28 11:16:33 PM 2026  list(learning_rate = 0.025, num_leaves = 200, min_data_in_leaf = 300, feature_fraction = 0.4, num_iterations = 500) AUC 0.926019241158537
#
# Fri Aug 28 11:16:47 PM 2026  list(learning_rate = 0.025, num_leaves = 200, min_data_in_leaf = 300, feature_fraction = 0.4, num_iterations = 700) AUC 0.925062575160828
#
# Fri Aug 28 11:17:02 PM 2026  list(learning_rate = 0.025, num_leaves = 200, min_data_in_leaf = 300, feature_fraction = 0.5, num_iterations = 500) AUC 0.926326788034834
#
# Fri Aug 28 11:17:18 PM 2026  list(learning_rate = 0.025, num_leaves = 200, min_data_in_leaf = 300, feature_fraction = 0.5, num_iterations = 700) AUC 0.925582895027917
#
# Fri Aug 28 11:17:34 PM 2026  list(learning_rate = 0.035, num_leaves = 90, min_data_in_leaf = 150, feature_fraction = 0.3, num_iterations = 500) AUC 0.926113935470663
#
# Fri Aug 28 11:17:49 PM 2026  list(learning_rate = 0.035, num_leaves = 90, min_data_in_leaf = 150, feature_fraction = 0.3, num_iterations = 700) AUC 0.925265487110569
#
# Fri Aug 28 11:18:05 PM 2026  list(learning_rate = 0.035, num_leaves = 90, min_data_in_leaf = 150, feature_fraction = 0.4, num_iterations = 500) AUC 0.925239066261883
#
# Fri Aug 28 11:18:21 PM 2026  list(learning_rate = 0.035, num_leaves = 90, min_data_in_leaf = 150, feature_fraction = 0.4, num_iterations = 700) AUC 0.926493401103232
#
# Fri Aug 28 11:18:37 PM 2026  list(learning_rate = 0.035, num_leaves = 90, min_data_in_leaf = 150, feature_fraction = 0.5, num_iterations = 500) AUC 0.924012965750505
#
# Fri Aug 28 11:18:52 PM 2026  list(learning_rate = 0.035, num_leaves = 90, min_data_in_leaf = 150, feature_fraction = 0.5, num_iterations = 700) AUC 0.926132973736399
#
# Fri Aug 28 11:19:07 PM 2026  list(learning_rate = 0.035, num_leaves = 90, min_data_in_leaf = 300, feature_fraction = 0.3, num_iterations = 500) AUC 0.926279545138178
#
# Fri Aug 28 11:19:23 PM 2026  list(learning_rate = 0.035, num_leaves = 90, min_data_in_leaf = 300, feature_fraction = 0.3, num_iterations = 700) AUC 0.926511179148321
#
# Fri Aug 28 11:19:38 PM 2026  list(learning_rate = 0.035, num_leaves = 90, min_data_in_leaf = 300, feature_fraction = 0.4, num_iterations = 500) AUC 0.925745425957543
#
# Fri Aug 28 11:19:53 PM 2026  list(learning_rate = 0.035, num_leaves = 90, min_data_in_leaf = 300, feature_fraction = 0.4, num_iterations = 700) AUC 0.924969531429628
#
# Fri Aug 28 11:20:08 PM 2026  list(learning_rate = 0.035, num_leaves = 90, min_data_in_leaf = 300, feature_fraction = 0.5, num_iterations = 500) AUC 0.925540313791835
#
# Fri Aug 28 11:20:24 PM 2026  list(learning_rate = 0.035, num_leaves = 90, min_data_in_leaf = 300, feature_fraction = 0.5, num_iterations = 700) AUC 0.926557547698675
#
# Fri Aug 28 11:20:39 PM 2026  list(learning_rate = 0.035, num_leaves = 140, min_data_in_leaf = 150, feature_fraction = 0.3, num_iterations = 500) AUC 0.925371047660392
#
# Fri Aug 28 11:20:54 PM 2026  list(learning_rate = 0.035, num_leaves = 140, min_data_in_leaf = 150, feature_fraction = 0.3, num_iterations = 700) AUC 0.926323770198357
#
# Fri Aug 28 11:21:09 PM 2026  list(learning_rate = 0.035, num_leaves = 140, min_data_in_leaf = 150, feature_fraction = 0.4, num_iterations = 500) AUC 0.925676234555464
#
# Fri Aug 28 11:21:24 PM 2026  list(learning_rate = 0.035, num_leaves = 140, min_data_in_leaf = 150, feature_fraction = 0.4, num_iterations = 700) AUC 0.926742177024007
#
# Fri Aug 28 11:21:39 PM 2026  list(learning_rate = 0.035, num_leaves = 140, min_data_in_leaf = 150, feature_fraction = 0.5, num_iterations = 500) AUC 0.925370933121113
#
# Fri Aug 28 11:21:53 PM 2026  list(learning_rate = 0.035, num_leaves = 140, min_data_in_leaf = 150, feature_fraction = 0.5, num_iterations = 700) AUC 0.926671603025575
#
# Fri Aug 28 11:22:08 PM 2026  list(learning_rate = 0.035, num_leaves = 140, min_data_in_leaf = 300, feature_fraction = 0.3, num_iterations = 500) AUC 0.926406529508322
#
# Fri Aug 28 11:22:22 PM 2026  list(learning_rate = 0.035, num_leaves = 140, min_data_in_leaf = 300, feature_fraction = 0.3, num_iterations = 700) AUC 0.925575868992248
#
# Fri Aug 28 11:22:37 PM 2026  list(learning_rate = 0.035, num_leaves = 140, min_data_in_leaf = 300, feature_fraction = 0.4, num_iterations = 500) AUC 0.925803715060228
#
# Fri Aug 28 11:22:51 PM 2026  list(learning_rate = 0.035, num_leaves = 140, min_data_in_leaf = 300, feature_fraction = 0.4, num_iterations = 700) AUC 0.92424674086231
#
# Fri Aug 28 11:23:06 PM 2026  list(learning_rate = 0.035, num_leaves = 140, min_data_in_leaf = 300, feature_fraction = 0.5, num_iterations = 500) AUC 0.926773561371962
#
# Fri Aug 28 11:23:20 PM 2026  list(learning_rate = 0.035, num_leaves = 140, min_data_in_leaf = 300, feature_fraction = 0.5, num_iterations = 700) AUC 0.924832874174071
#
# Fri Aug 28 11:23:35 PM 2026  list(learning_rate = 0.035, num_leaves = 200, min_data_in_leaf = 150, feature_fraction = 0.3, num_iterations = 500) AUC 0.925907505158874
#
# Fri Aug 28 11:23:49 PM 2026  list(learning_rate = 0.035, num_leaves = 200, min_data_in_leaf = 150, feature_fraction = 0.3, num_iterations = 700) AUC 0.926091254099163
#
# Fri Aug 28 11:24:04 PM 2026  list(learning_rate = 0.035, num_leaves = 200, min_data_in_leaf = 150, feature_fraction = 0.4, num_iterations = 500) AUC 0.924707451398515
#
# Fri Aug 28 11:24:18 PM 2026  list(learning_rate = 0.035, num_leaves = 200, min_data_in_leaf = 150, feature_fraction = 0.4, num_iterations = 700) AUC 0.926177744590676
#
# Fri Aug 28 11:24:33 PM 2026  list(learning_rate = 0.035, num_leaves = 200, min_data_in_leaf = 150, feature_fraction = 0.5, num_iterations = 500) AUC 0.926189541977766
#
# Fri Aug 28 11:24:47 PM 2026  list(learning_rate = 0.035, num_leaves = 200, min_data_in_leaf = 150, feature_fraction = 0.5, num_iterations = 700) AUC 0.92650476892963
#
# Fri Aug 28 11:25:01 PM 2026  list(learning_rate = 0.035, num_leaves = 200, min_data_in_leaf = 300, feature_fraction = 0.3, num_iterations = 500) AUC 0.926021914635402
#
# Fri Aug 28 11:25:16 PM 2026  list(learning_rate = 0.035, num_leaves = 200, min_data_in_leaf = 300, feature_fraction = 0.3, num_iterations = 700) AUC 0.926407932337512
#
# Fri Aug 28 11:25:30 PM 2026  list(learning_rate = 0.035, num_leaves = 200, min_data_in_leaf = 300, feature_fraction = 0.4, num_iterations = 500) AUC 0.925696894558244
#
# Fri Aug 28 11:25:45 PM 2026  list(learning_rate = 0.035, num_leaves = 200, min_data_in_leaf = 300, feature_fraction = 0.4, num_iterations = 700) AUC 0.925421589952199
#
# Fri Aug 28 11:25:59 PM 2026  list(learning_rate = 0.035, num_leaves = 200, min_data_in_leaf = 300, feature_fraction = 0.5, num_iterations = 500) AUC 0.924758145997669
#
# Fri Aug 28 11:26:14 PM 2026  list(learning_rate = 0.035, num_leaves = 200, min_data_in_leaf = 300, feature_fraction = 0.5, num_iterations = 700) AUC 0.926051762167358

# %%
# veo que tiene la tabla DESPUES de procesar
tb_nueva
# Out:
#     learning_rate num_leaves min_data_in_leaf feature_fraction num_iterations
# 1   0.015          90        150              0.3              500
# 2   0.015          90        150              0.3              700
# 3   0.015          90        150              0.4              500
# 4   0.015          90        150              0.4              700
# 5   0.015          90        150              0.5              500
# 6   0.015          90        150              0.5              700
# 7   0.015          90        300              0.3              500
# 8   0.015          90        300              0.3              700
# 9   0.015          90        300              0.4              500
# 10  0.015          90        300              0.4              700
# 11  0.015          90        300              0.5              500
# 12  0.015          90        300              0.5              700
# 13  0.015         140        150              0.3              500
# 14  0.015         140        150              0.3              700
# 15  0.015         140        150              0.4              500
# 16  0.015         140        150              0.4              700
# 17  0.015         140        150              0.5              500
# 18  0.015         140        150              0.5              700
# 19  0.015         140        300              0.3              500
# 20  0.015         140        300              0.3              700
# 21  0.015         140        300              0.4              500
# 22  0.015         140        300              0.4              700
# 23  0.015         140        300              0.5              500
# 24  0.015         140        300              0.5              700
# 25  0.015         200        150              0.3              500
# 26  0.015         200        150              0.3              700
# 27  0.015         200        150              0.4              500
# 28  0.015         200        150              0.4              700
# 29  0.015         200        150              0.5              500
# 30  0.015         200        150              0.5              700
# ⋮   ⋮             ⋮          ⋮                ⋮                ⋮
# 79  0.035          90        300              0.3              500
# 80  0.035          90        300              0.3              700
# 81  0.035          90        300              0.4              500
# 82  0.035          90        300              0.4              700
# 83  0.035          90        300              0.5              500
# 84  0.035          90        300              0.5              700
# 85  0.035         140        150              0.3              500
# 86  0.035         140        150              0.3              700
# 87  0.035         140        150              0.4              500
# 88  0.035         140        150              0.4              700
# 89  0.035         140        150              0.5              500
# 90  0.035         140        150              0.5              700
# 91  0.035         140        300              0.3              500
# 92  0.035         140        300              0.3              700
# 93  0.035         140        300              0.4              500
# 94  0.035         140        300              0.4              700
# 95  0.035         140        300              0.5              500
# 96  0.035         140        300              0.5              700
# 97  0.035         200        150              0.3              500
# 98  0.035         200        150              0.3              700
# 99  0.035         200        150              0.4              500
# 100 0.035         200        150              0.4              700
# 101 0.035         200        150              0.5              500
# 102 0.035         200        150              0.5              700
# 103 0.035         200        300              0.3              500
# 104 0.035         200        300              0.3              700
# 105 0.035         200        300              0.4              500
# 106 0.035         200        300              0.4              700
# 107 0.035         200        300              0.5              500
# 108 0.035         200        300              0.5              700
#     AUC
# 1   0.9258935
# 2   0.9249740
# 3   0.9266316
# 4   0.9252687
# 5   0.9253178
# 6   0.9258736
# 7   0.9267072
# 8   0.9267076
# 9   0.9243653
# 10  0.9263531
# 11  0.9256494
# 12  0.9247440
# 13  0.9257021
# 14  0.9251322
# 15  0.9260600
# 16  0.9250187
# 17  0.9257771
# 18  0.9264439
# 19  0.9250079
# 20  0.9257486
# 21  0.9259796
# 22  0.9259307
# 23  0.9245181
# 24  0.9254372
# 25  0.9254132
# 26  0.9280830
# 27  0.9256129
# 28  0.9264818
# 29  0.9236838
# 30  0.9250928
# ⋮   ⋮
# 79  0.9262795
# 80  0.9265112
# 81  0.9257454
# 82  0.9249695
# 83  0.9255403
# 84  0.9265575
# 85  0.9253710
# 86  0.9263238
# 87  0.9256762
# 88  0.9267422
# 89  0.9253709
# 90  0.9266716
# 91  0.9264065
# 92  0.9255759
# 93  0.9258037
# 94  0.9242467
# 95  0.9267736
# 96  0.9248329
# 97  0.9259075
# 98  0.9260913
# 99  0.9247075
# 100 0.9261777
# 101 0.9261895
# 102 0.9265048
# 103 0.9260219
# 104 0.9264079
# 105 0.9256969
# 106 0.9254216
# 107 0.9247581
# 108 0.9260518

# %%
fwrite( tb_nueva,
  file= "tb_grid_serach_01.txt",
  sep="\t",
  append= TRUE
)

# %%
setorder( tb_nueva, -AUC)
PARAM$out$lgbm$AUC <- tb_nueva[1, AUC]
PARAM$out$lgbm$mejores_hiperparametros <- as.list( tb_nueva[1] )
PARAM$out$lgbm$mejores_hiperparametros$AUC <- NULL
PARAM$out$lgbm$mejores_hiperparametros
# Out:
# $learning_rate
# [1] 0.015
#
# $num_leaves
# [1] 200
#
# $min_data_in_leaf
# [1] 150
#
# $feature_fraction
# [1] 0.3
#
# $num_iterations
# [1] 700

# %%
write_yaml( PARAM, file="PARAM.yml")

# %% [markdown]
# ## 2.3  Produccion

# %% [markdown]
# ### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %%
setwd("/content/buckets/b1/exp")
experimento <- paste0("exp", PARAM$experimento)
dir.create(experimento, showWarnings= FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento ))

# %% [markdown]
# #### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización de hiperparametros

# %%
# clase01
dataset[, clase01 := ifelse(clase_ternaria %in% c("BAJA+1", "BAJA+2"), 1L, 0L)]

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[, campos_buenos, with= FALSE]),
  label= dataset_train[, clase01]
)

# %% [markdown]
# #### Final Training Hyperparameters

# %%
param_final <- modifyList(PARAM$lgbm$param_fijos,
  PARAM$out$lgbm$mejores_hiperparametros)

param_final
# Out:
# $boosting
# [1] "gbdt"
#
# $objective
# [1] "binary"
#
# $metric
# [1] "auc"
#
# $first_metric_only
# [1] FALSE
#
# $boost_from_average
# [1] TRUE
#
# $feature_pre_filter
# [1] FALSE
#
# $force_row_wise
# [1] TRUE
#
# $verbosity
# [1] -100
#
# $seed
# [1] 115879
#
# $max_depth
# [1] -1
#
# $min_gain_to_split
# [1] 0
#
# $min_sum_hessian_in_leaf
# [1] 0.001
#
# $lambda_l1
# [1] 0
#
# $lambda_l2
# [1] 0
#
# $max_bin
# [1] 31
#
# $bagging_fraction
# [1] 1
#
# $pos_bagging_fraction
# [1] 1
#
# $neg_bagging_fraction
# [1] 1
#
# $is_unbalance
# [1] FALSE
#
# $scale_pos_weight
# [1] 1
#
# $drop_rate
# [1] 0.1
#
# $max_drop
# [1] 50
#
# $skip_drop
# [1] 0.5
#
# $extra_trees
# [1] FALSE
#
# $num_iterations
# [1] 700
#
# $learning_rate
# [1] 0.015
#
# $feature_fraction
# [1] 0.3
#
# $num_leaves
# [1] 200
#
# $min_data_in_leaf
# [1] 150

# %% [markdown]
# #### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
# este punto es muy SUTIL  y será revisado en la Clase 05

param_normalizado <- copy(param_final)
param_normalizado$min_data_in_leaf <-  round(param_final$min_data_in_leaf / PARAM$trainingstrategy$undersampling)

# %%
  # entreno LightGBM

  modelo_final <- lgb.train(
    data= dtrain,
    param= param_normalizado
  )

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(modelo_final))
archivo_importancia <- "impo.txt"

fwrite(tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(modelo_final, "modelo.txt" )

# %% [markdown]
# ### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
# aplico el modelo a los datos sin clase
dfuture <- dataset[foto_mes == 202109]

# aplico el modelo a los datos nuevos
prediccion <- predict(
  modelo_final,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# #### Tabla Prediccion

# %%
# tabla de prediccion

tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion ]

# grabo las probabilidad del modelo
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# Kaggle Competition Submit

# %%
# genero archivos con los  "envios" mejores
# suba TODOS los archivos a Kaggle

# ordeno por probabilidad descendente
setorder(tb_prediccion, -prob)

dir.create("kaggle")

for (envios in PARAM$kaggle$cortes) {

  tb_prediccion[, Predicted := 0L] # seteo inicial a 0
  tb_prediccion[1:envios, Predicted := 1L] # marclo los primeros

  archivo_kaggle <- paste0("./kaggle/KA", PARAM$experimento, "_", envios, ".csv")

  # grabo el archivo
  fwrite(tb_prediccion[, list(numero_de_cliente, Predicted)],
    file= archivo_kaggle,
    sep= ","
  )

  # subida a Kaggle, armo la linea de comando
  comando <- "kaggle competitions submit"
  competencia <- paste("-c", PARAM$kaggle$competencia)
  arch <- paste( "-f", archivo_kaggle)

  mensaje <- paste0("-m 'envios=", envios,
  "  semilla=", PARAM$semilla_primigenia,
    "'" )

  linea <- paste( comando, competencia, arch, mensaje)

  salida <- system(linea, intern=TRUE) # el submit a Kaggle
  cat(salida, "\n")
  Sys.sleep(45)
}
# Out:
# Warning: Looks like you're using an outdated `kaggle` version (installed: 2.0.2), please consider upgrading to the latest version (2.2.2) Successfully submitted to UTN 2026 Inicial
# Warning: Looks like you're using an outdated `kaggle` version (installed: 2.0.2), please consider upgrading to the latest version (2.2.2) Successfully submitted to UTN 2026 Inicial
# Warning: Looks like you're using an outdated `kaggle` version (installed: 2.0.2), please consider upgrading to the latest version (2.2.2) Successfully submitted to UTN 2026 Inicial
# Warning: Looks like you're using an outdated `kaggle` version (installed: 2.0.2), please consider upgrading to the latest version (2.2.2) Successfully submitted to UTN 2026 Inicial
# Warning: Looks like you're using an outdated `kaggle` version (installed: 2.0.2), please consider upgrading to the latest version (2.2.2) Successfully submitted to UTN 2026 Inicial
# Warning: Looks like you're using an outdated `kaggle` version (installed: 2.0.2), please consider upgrading to the latest version (2.2.2) Successfully submitted to UTN 2026 Inicial
# Warning: Looks like you're using an outdated `kaggle` version (installed: 2.0.2), please consider upgrading to the latest version (2.2.2) Successfully submitted to UTN 2026 Inicial

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Fri Aug 28 11:34:06 PM 2026"

# %% [markdown]
# Finalmente usted deberá cargar el resultado de su corrida en la Google Sheet Colaborativa,  hoja **TareaHogar-04**
# <br> Siéntase libre de agregar las columnas que hagan falta a la planilla

# %% [markdown]
# Seguramente usted realice varias corridas de este script con distintos conjuntos de hiperparámetros, siempre cambiandole el nombre al script  y también cambiando el nombre del experimento,  deberá TODAS esas corridas en distintas lineas de la  Google Sheet Colaborativa, hoja **TareaHogar-04**

# %% [markdown]
# Siéntase libre de agregar columnas a la hoja **TareaHogar-04**  en caso de ser necesario.
