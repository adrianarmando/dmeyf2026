# %%
# Ejemplo: Ganancia máxima o AUC de validación obtenido por cada semilla (ej. 5 o 10 semillas)
# Las semillas deben ser exactamente las mismas en ambos experimentos

# Experimento 910_01
# metricas_baseline <- c(87061, 85150, 88390, 87227, 81412, 89553, 81910, 86978, 81412, 86812)
# metricas_ga       <- c(93125, 87393, 80996, 85482, 87559, 87144, 87642, 83655, 92959, 83489) 

# Experimento 910_02
metricas_baseline <- c(87061, 85150, 88390, 87227, 81412, 89553, 81910, 86978, 81412, 86812)
metricas_ga       <- c(87476, 86646, 83489, 87227, 88473, 89968, 91048, 90301, 83489, 91048) 



# Test pareado unilateral (probando si GA es mayor que Baseline)
wt <- wilcox.test(
  x = metricas_ga,
  y = metricas_baseline,
  paired = TRUE,
  alternative = "greater"
)

print(wt)
# Out:
# Warning message in wilcox.test.default(x = metricas_ga, y = metricas_baseline, paired = TRUE, :
# “cannot compute exact p-value with ties”
# 	Wilcoxon signed rank test with continuity correction
#
# data:  metricas_ga and metricas_baseline
# V = 33, p-value = 0.305
# alternative hypothesis: true location shift is greater than 0
